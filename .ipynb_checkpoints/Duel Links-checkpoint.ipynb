# %%
import numpy as np
import os
import pandas as pd 
import datetime
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter

# %%
allUltraDataFrame = pd.read_csv('allUltra.csv', engine='python', index_col=0)


allSuperDataFrame = pd.read_csv('allSuper.csv', engine='python', index_col=0)
allRareDataFrame = pd.read_csv('allRare.csv', engine='python', index_col=0)

# %%
print("Printing All Ultra")
print(allUltraDataFrame)

print("Printing All Super")
print(allSuperDataFrame)

print("Printing All Rare")
print(allRareDataFrame)
# Out:
# Printing All Ultra
#          P(H)         P(D|H)          P(D)         P(H|D)
# 0    0.000000   0.000000e+00  5.050000e-14   0.000000e+00
# 1    0.009901   4.010000e-19  5.050000e-14   7.850000e-08
# 2    0.019802   8.140000e-17  5.050000e-14   3.190000e-05
# 3    0.029703   1.230000e-15  5.050000e-14   7.238110e-04
# 4    0.039604   6.390000e-15  5.050000e-14   5.005726e-03
# 5    0.049505   1.830000e-14  5.050000e-14   1.797766e-02
# 6    0.059406   3.610000e-14  5.050000e-14   4.249445e-02
# 7    0.069307   5.470000e-14  5.050000e-14   7.500906e-02
# 8    0.079208   6.800000e-14  5.050000e-14   1.066049e-01
# 9    0.089109   7.260000e-14  5.050000e-14   1.280492e-01
# 10   0.099010   6.860000e-14  5.050000e-14   1.343548e-01
# 11   0.108911   5.850000e-14  5.050000e-14   1.260673e-01
# 12   0.118812   4.580000e-14  5.050000e-14   1.076268e-01
# 13   0.128713   3.320000e-14  5.050000e-14   8.469748e-02
# 14   0.138614   2.260000e-14  5.050000e-14   6.206181e-02
# ...

# %%
#ax = allUltraDataFrame.plot(kind='line', title ="Prior",figsize=(15,10),legend=True, fontsize=12)
#ax.set_xlabel("Day of the week",fontsize=12)
#ax.set_ylabel("Price (USD)",fontsize=12)
#plt.show()

#allUltraDataFrame.P(H).plot() # Vertex is the x-axis
#plt.show()

allUltraDataFrame[['P(H)','P(D|H)', 'P(D)','P(H|D)']].plot()
print("All Ultra")
plt.show()



allSuperDataFrame[['P(H)','P(D|H)', 'P(D)','P(H|D)']].plot()
print("All Super")
plt.show()

allRareDataFrame[['P(H)','P(D|H)', 'P(D)','P(H|D)']].plot()
print("All Rare")
plt.show()
# Out:
# All Ultra
# All Super
# All Rare
