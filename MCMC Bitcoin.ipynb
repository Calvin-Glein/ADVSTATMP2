# %%
import numpy
import os
import pandas as pd 
import datetime
import matplotlib.pyplot as plt


#para mawala ellipses
#pd.set_option('display.max_rows', 100000)
#parse the dates mula sa dataset
def dateparse (time_in_secs):    
    return datetime.datetime.fromtimestamp(float(time_in_secs))



#dataset is from coinbase, exchange sya for cryptocurrency

#this is our Actual data (not the priori)
#df = df = pd.read_csv('coinbaseUSD_1-min_data_2014-12-01_to_2017-10-20.csv', encoding='utf-8', engine='python',  parse_dates=True, date_parser=dateparse, index_col=[0])


#print(df.tail(1000))


#Date interval from july 17 to july 23
#prior data from bitcoinforecast.com
priorDataFrame = pd.read_csv('predicted.csv', encoding='utf-8', engine='python')
#actual data from bitcoinaverage, exchange and api platform sya
actualDataFrame = pd.read_csv('actual.csv', encoding='utf-8', engine='python')
#combined datas
combinedDataFrame = pd.concat([priorDataFrame, actualDataFrame], axis=1)


print("Printing prior")
print(priorDataFrame)
print()
print("Printing actual")
print(actualDataFrame)
print()
print("Printing combined")
print(combinedDataFrame)

#for now one week lang dataset, if may time tayo, we can perform mcmc sa a few more weeks, then get the average of all of them collectively.
#Tapos end goal natin is to tell kung kelan optimal time mag deposit and optimal time mag withdraw between Sunday to Saturday
# Out:
# Printing prior
#            Date    Price
# 0  July-17-2017  2594.94
# 1  July-18-2017  2545.68
# 2  July-19-2017  2566.71
# 3  July-20-2017  2588.05
# 4  July-21-2017  2609.68
# 5  July-22-2017  2631.62
# 6  July-23-2017  2653.86
#
# Printing actual
#            Date    Price
# 0  July-17-2017  2050.82
# 1  July-18-2017  2269.79
# 2  July-19-2017  2308.37
# 3  July-20-2017  2486.87
# 4  July-21-2017  2720.35
# 5  July-22-2017  2776.55
# 6  July-23-2017  2773.24
#
# Printing combined
#            Date    Price          Date    Price
# 0  July-17-2017  2594.94  July-17-2017  2050.82
# 1  July-18-2017  2545.68  July-18-2017  2269.79
# 2  July-19-2017  2566.71  July-19-2017  2308.37
# 3  July-20-2017  2588.05  July-20-2017  2486.87
# 4  July-21-2017  2609.68  July-21-2017  2720.35
# 5  July-22-2017  2631.62  July-22-2017  2776.55
# 6  July-23-2017  2653.86  July-23-2017  2773.24

# %%
ax = priorDataFrame.plot(kind='line', title ="Prior",figsize=(15,10),legend=True, fontsize=12)
ax.set_xlabel("Day of the week",fontsize=12)
ax.set_ylabel("Price (USD)",fontsize=12)
plt.show()


ax = actualDataFrame.plot(kind='line', title ="Actual",figsize=(15,10),legend=True, fontsize=20)
ax.set_xlabel("Day of the week",fontsize=12)
ax.set_ylabel("Price (USD)",fontsize=12)
plt.show()


ax = combinedDataFrame.plot(kind='line', title ="Combined",figsize=(15,10),legend=True, fontsize=20)
ax.set_xlabel("Day of the week",fontsize=12)
ax.set_ylabel("Price (USD)",fontsize=12)
plt.show()
